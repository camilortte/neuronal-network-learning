# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4,5,6,7,8])
plt.grid()
plt.show()

# %%
x = np.arange(10)
y = x * x

# %%
plt.plot(x, y)

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.subplot(141)
plt.bar(names, values)

plt.subplot(142)
plt.scatter(names, values)

plt.subplot(143)
plt.plot(names, values)
plt.suptitle('Categorical')
# Out:
# Text(0.5, 0.98, 'Categorical')
